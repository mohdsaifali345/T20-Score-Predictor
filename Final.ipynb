# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df

# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 404896      3350    Sri Lanka    Australia  19.3     1                0
# 404897      3350    Sri Lanka    Australia  19.4     0                0
# 404898      3350    Sri Lanka    Australia  19.5     0      DM de Silva
# 404899      3350    Sri Lanka    Australia  19.6     2                0
# 404900      3350    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8671
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 404896      3350    Sri Lanka    Australia  19.3     1                0
# 404897      3350    Sri Lanka    Australia  19.4     0                0
# 404898      3350    Sri Lanka    Australia  19.5     0      DM de Silva
# 404899      3350    Sri Lanka    Australia  19.6     2                0
# 404900      3350    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 404896      3350    Sri Lanka    Australia  19.3     1                0
# 404897      3350    Sri Lanka    Australia  19.4     0                0
# 404898      3350    Sri Lanka    Australia  19.5     0      DM de Silva
# 404899      3350    Sri Lanka    Australia  19.6     2                0
# 404900      3350    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
# Convert 'runs' column to numeric dtype
df['runs'] = pd.to_numeric(df['runs'])

# Apply cumsum grouped by 'match_id'
df['current_score'] = df.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\3609490072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs'] = pd.to_numeric(df['runs'])
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\3609490072.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 404896      3350    Sri Lanka    Australia  19.3     1                 8
# 404897      3350    Sri Lanka    Australia  19.4     0                 8
# 404898      3350    Sri Lanka    Australia  19.5     0                 9
# 404899      3350    Sri Lanka    Australia  19.6     2                 9
# 404900      3350    Sri Lanka    Australia  19.7     1                 9
#
#              city over ball_no  balls_bowled  balls_left  wickets_left  \
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\3575727727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\3575727727.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\562775579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\2304996896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\2304996896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# ...

# %%
import pandas as pd

# Convert 'player_dismissed' column to numeric, replacing '0' with 0
df['player_dismissed'] = pd.to_numeric(df['player_dismissed'].replace('0', 0))

# Apply cumsum after conversion
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# Calculate remaining wickets
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\4000880955.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = pd.to_numeric(df['player_dismissed'].replace('0', 0))
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\4000880955.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
# ...

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 404896      3350    Sri Lanka    Australia  19.3     1               490
# 404897      3350    Sri Lanka    Australia  19.4     0               498
# 404898      3350    Sri Lanka    Australia  19.5     0               507
# 404899      3350    Sri Lanka    Australia  19.6     2               516
# 404900      3350    Sri Lanka    Australia  19.7     1               525
#
#              city over ball_no  balls_bowled  balls_left  wickets_left  \
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\2902028393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 404896      3350    Sri Lanka    Australia  19.3     1               490
# 404897      3350    Sri Lanka    Australia  19.4     0               498
# 404898      3350    Sri Lanka    Australia  19.5     0               507
# 404899      3350    Sri Lanka    Australia  19.6     2               516
# 404900      3350    Sri Lanka    Australia  19.7     1               525
#
#              city over ball_no  balls_bowled  balls_left  wickets_left  \
# ...

# %%
last_five = []
last_five_indices = []  # Store the indices for alignment

for id in match_ids:
    runs = groups.get_group(id)['runs']
    # Filter out non-numeric values
    numeric_runs = runs.apply(pd.to_numeric, errors='coerce')
    # Apply rolling sum to numeric values only
    rolling_sum = numeric_runs.rolling(window=30).sum()
    # Extend the last_five list with the rolling sum values and their indices
    last_five.extend(rolling_sum.dropna().values.tolist())
    last_five_indices.extend(rolling_sum.dropna().index.tolist())

# Adjust the length of last_five to match the number of rows in the DataFrame
num_rows_diff = len(df) - len(last_five)
last_five.extend([np.nan] * num_rows_diff)

# Assign 'last_five' to the 'last_five' column
df['last_five'] = last_five
# Out:
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\3982651248.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df['last_five'] = last_five
# Out:
# C:\Users\SOFIA SULTHANA\AppData\Local\Temp\ipykernel_25652\1102800720.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
print("Length of 'last_thirty':", len(last_thirty))
print("Number of rows in the DataFrame:", len(df))
# Out:
# Length of 'last_thirty': 12587
# Number of rows in the DataFrame: 51109

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 404896      3350    Sri Lanka    Australia  19.3     1               490
# 404897      3350    Sri Lanka    Australia  19.4     0               498
# 404898      3350    Sri Lanka    Australia  19.5     0               507
# 404899      3350    Sri Lanka    Australia  19.6     2               516
# 404900      3350    Sri Lanka    Australia  19.7     1               525
#
#              city over ball_no  balls_bowled  balls_left  wickets_left  \
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12169
# runs_x               0
# dtype: int64

# %%
import pandas as pd

# Assuming df is your DataFrame and 'last_five' is the column you want to clean
df = df.dropna(subset=['last_five']).copy()

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12169
# runs_x               0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#       batting_team  bowling_team          city  current_score  balls_left  \
# 15836  West Indies  South Africa  Johannesburg             95          64
# 24826     Pakistan       England      Barbados              7         117
#
#        wickets_left        crr  last_five  runs_x
# 15836            10  10.178571       47.0     205
# 24826            10  14.000000       48.0     147

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team        city  current_score  balls_left  \
# 40552     Australia   West Indies      Mirpur              4         115
# 34420   West Indies     Sri Lanka     Colombo            101          20
# 47464   New Zealand         India      Nagpur            113           4
# 125       Australia     Sri Lanka    Adelaide              0         119
# 10322  South Africa         India  Chandigarh             34          88
# ...             ...           ...         ...            ...         ...
# 31731         India   Afghanistan     Colombo             16         105
# 10244     Australia  South Africa   Cape Town            125          42
# 33065         India     Australia     Colombo            122          15
# 25606   West Indies         India    Barbados             26          89
# 18523   New Zealand       England  Manchester             14         101
#
#        wickets_left       crr  last_five
# 40552            10  4.800000        NaN
# ...

# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 660.6 kB/s eta 0:02:31
#    ---------------------------------------- 0.3/99.8 MB 3.4 MB/s eta 0:00:30
#    ---------------------------------------- 0.9/99.8 MB 6.8 MB/s eta 0:00:15
#     --------------------------------------- 1.7/99.8 MB 10.7 MB/s eta 0:00:10
#     --------------------------------------- 2.2/99.8 MB 10.0 MB/s eta 0:00:10
#     --------------------------------------- 2.4/99.8 MB 9.1 MB/s eta 0:00:11
#    - -------------------------------------- 2.6/99.8 MB 8.3 MB/s eta 0:00:12
#    - -------------------------------------- 2.8/99.8 MB 7.7 MB/s eta 0:00:13
#    - -------------------------------------- 2.9/99.8 MB 7.2 MB/s eta 0:00:14
#    - -------------------------------------- 3.0/99.8 MB 6.9 MB/s eta 0:00:14
#    - -------------------------------------- 3.2/99.8 MB 6.4 MB/s eta 0:00:16
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# C:\anaconda\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.9786428847297514
# 2.149097188674548

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '2.0.3'
